# %% [markdown]
# For the given URL that host a data file, send a http request to retrieve the data

# %%
url = "https://s3-us-gov-west-1.amazonaws.com/cg-baa85e06-1bdd-4672-9e3a-36333c05c6ce/ca-gov__download_requests__last30.csv"

# %%
import requests
# Out:
# {'x-amz-id-2': 'dh6s3+ODCOI3prZBEGWpOzAOMhKwtsF4vMIIjTb3UfWafCgMrh3QZtx7TKxwrxcjGJO0fVvntaT+nHygXWjNULwuW53XvsdP', 'x-amz-request-id': '1PRYWE1DQ4BV0219', 'Date': 'Mon, 25 Aug 2025 16:21:52 GMT', 'Last-Modified': 'Fri, 01 Nov 2024 00:18:53 GMT', 'ETag': '"d70cd1b77fcc6fe6146f713e496a788b"', 'x-amz-server-side-encryption': 'AES256', 'Accept-Ranges': 'bytes', 'Content-Type': 'binary/octet-stream', 'Content-Length': '197639', 'Server': 'AmazonS3'}
# ...
