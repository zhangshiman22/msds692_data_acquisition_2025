# %%
import requests

# %% [markdown]
# GET Request

# %%
url = 'https://www.usfca.edu/arts-sciences/programs/graduate/data-science'
headers = ''
r = requests.get(url, headers=headers) # r is a resopnse
print(r.headers)
print(r.content)
# Out:
# {'Connection': 'keep-alive', 'Content-Length': '240748', 'Cache-Control': 'max-age=21600, public', 'Content-Language': 'en', 'Content-Type': 'text/html; charset=UTF-8', 'Etag': 'W/"1756125302"', 'Expires': 'Sun, 19 Nov 1978 05:00:00 GMT', 'Last-Modified': 'Mon, 25 Aug 2025 12:35:02 GMT', 'Server': 'nginx', 'Strict-Transport-Security': 'max-age=300', 'X-Content-Type-Options': 'nosniff', 'X-Drupal-Cache': 'HIT', 'X-Drupal-Dynamic-Cache': 'MISS', 'X-Frame-Options': 'ALLOW-FROM https://usfca.instructure.com', 'X-Generator': 'Drupal 9 (https://www.drupal.org)', 'X-Pantheon-Styx-Hostname': 'styx-fe2-b-5765cf765c-rrnmc', 'X-Styx-Req-Id': '9b178aa8-81cf-11f0-b960-0abf7c7c4b4a', 'X-Ua-Compatible': 'IE=edge', 'Age': '0', 'Accept-Ranges': 'bytes', 'Via': '1.1 varnish, 1.1 varnish, 1.1 varnish, 1.1 varnish', 'Date': 'Mon, 25 Aug 2025 16:21:50 GMT', 'X-Served-By': 'cache-chi-kigq8000179-CHI, cache-pao-kpao1770060-PAO, cache-pao-kpao1770063-PAO, cache-pao-kpao1770063-PAO', 'X-Cache': 'MISS, MISS, MISS, MISS', 'X-Cache-Hits': '0, 0, 0, 0', 'X-Timer': 'S1756138911.831407,VS0,VE150', 'Vary': 'Accept-Encoding, Cookie, Cookie, Cookie'}
# b'<!DOCTYPE html>\n<html lang="en" dir="ltr" prefix="og: https://ogp.me/ns#">\n  <head>\n<script>\n    // Define dataLayer and the gtag function.\n    window.dataLayer = window.dataLayer || [];\n    function gtag(){dataLayer.push(arguments);}\n    // Default ad_storage to \'denied\'.\n    gtag(\'consent\', \'default\', {\n        ad_storage: "granted",\n        analytics_storage: "granted",\n        ad_user_data: "granted",\n        ad_personalization: "granted",\n        \'wait_for_update\': 500 // wait this many ms to check for consent update before sending network requests\n    });\n    // If ads_storage is denied, ads data (like gclid and gbraid) is redacted from URLs\n    gtag(\'set\', \'ads_data_redaction\', true);\n    // If a consent update is not received before the next page load, some information will be passed through the URL for continuity\n    gtag(\'set\', \'url_passthrough\', true);\n</script>\n<!-- OneTrust Cookies Consent Notice start for usfca.edu -->\n  <script src="https://cdn.cookielaw.org/scripttemplates/otSDKStub.js" type="text/javascript" charset="UTF-8" data-domain-script="018e5283-039b-7552-b02d-f856f49fa35e" ></script>\n<script type="text/javascript">\nfunction OptanonWrapper() { }\n</script>\n<!-- OneTrust Cookies Consent Notice end for usfca.edu -->\n\n    <meta charset="utf-8" /><script type="text/javascript">(window.NREUM||(NREUM={})).init={privacy:{cookies_enabled:true},ajax:{deny_list:["bam.nr-data.net"]},distributed_tracing:{enabled:true}};(window.NREUM||(NREUM={})).loader_config={agentID:"1103156521",accountID:"3553038",trustKey:"66686",xpid:"VwMCUlZQABAJUVlXBQUFUVM=",licenseKey:"NRJS-fa47084b7b5081b4604",applicationID:"958524277"};;/*! For license information please see nr-loader-spa-1.295.0.min.js.LICENSE.txt */\n(()=>{var e,t,r={8122:(e,t,r)=>{"use strict";r.d(t,{a:()=>i});var n=r(944);function i(e,t){try{if(!e||"object"!=typeof e)return(0,n.R)(3);if(!t||"object"!=typeof t)return(0,n.R)(4);const r=Object.create(Object.getPrototypeOf(t),Object.getOwnPropertyDescriptors(t)),o=0===Object.keys(r).length?e:r;for(let a in o)if(void 0!==e[a])try{if(null===e[a]){r[a]=null;continue}Array.isArray(e[a])&&Array.isArray(t[a])?r[a]=Array.from(new Set([...e[a],...t[a]])):"object"==typeof e[a]&&"object"==typeof t[a]?r[a]=i(e[a],t[a]):r[a]=e[a]}catch(e){r[a]||(0,n.R)(1,e)}return r}catch(e){(0,n.R)(2,e)}}},2555:(e,t,r)=>{"use strict";r.d(t,{D:()=>s,f:()=>a});var n=r(384),i=r(8122);const o={beacon:n.NT.beacon,errorBeacon:n.NT.errorBeacon,licenseKey:void 0,applicationID:void 0,sa:void 0,queueTime:void 0,applicationTime:void 0,ttGuid:void 0,user:void 0,account:void 0,product:void 0,extra:void 0,jsAttributes:{},userAttributes:void 0,atts:void 0,transactionName:void 0,tNamePlain:void 0};function a(e){try{return!!e.licenseKey&&!!e.errorBeacon&&!!e.applicationID}catch(e){return!1}}const s=e=>(0,i.a)(e,o)},9324:(e,t,r)=>{"use strict";r.d(t,{F3:()=>i,Xs:()=>o,Yq:()=>a,xv:()=>n});const n="1.295.0",i="PROD",o="CDN",a="^2.0.0-alpha.18"},6154:(e,t,r)=>{"use strict";r.d(t,{A4:()=>s,OF:()=>d,RI:()=>i,WN:()=>h,bv:()=>o,gm:()=>a,lR:()=>f,m:()=>u,mw:()=>c,sb:()=>l});var n=r(1863);const i="undefined"!=typeof window&&!!window.document,o="undefined"!=typeof WorkerGlobalScope&&("undefined"!=typeof self&&self instanceof WorkerGlobalScope&&self.navigator instanceof WorkerNavigator||"undefined"!=typeof globalThis&&globalThis instanceof WorkerGlobalScope&&globalThis.navigator instanceof WorkerNavigator),a=i?window:"undefined"!=typeof WorkerGlobalScope&&("undefined"!=typeof self&&self instanceof WorkerGlobalScope&&self||"undefined"!=typeof globalThis&&globalThis instanceof WorkerGlobalScope&&globalThis),s="complete"===a?.document?.readyState,c=Boolean("hidden"===a?.document?.visibilityState),u=""+a?.location,d=/iPad|iPhone|iPod/.test(a.navigator?.userAgent),l=d&&"undefined"==typeof SharedWorker,f=(()=>{const e=a.navigator?.userAgent?.match(/Firefox[/\\s](\\d+\\.\\d+)/);return Array.isArray(e)&&e.length>=2?+e[1]:0})(),h=Date.now()-(0 ...

# %%
url = "https://www.google.com/search"
payload = {"q":"USF Data Science"}
headers = ''

r = requests.get(url, params=payload, headers=headers)
print(r.url)
print(r.content)
# Out:
# https://www.google.com/search?q=USF+Data+Science
# b'<!DOCTYPE html><html lang="en"><head><title>Google Search</title><style>body{background-color:#fff}</style><script nonce="8aYszclZBxSSSFfh7Q-_zw">window.google = window.google || {};window.google.c = window.google.c || {ezx:false,cap:0};</script></head><body><noscript><style>table,div,span,p{display:none}</style><meta content="0;url=/httpservice/retry/enablejs?sei=n42saLueMbbV1sQPo5eHqAg" http-equiv="refresh"><div style="display:block">Please click <a href="/httpservice/retry/enablejs?sei=n42saLueMbbV1sQPo5eHqAg">here</a> if you are not redirected within a few seconds.</div></noscript><script nonce="8aYszclZBxSSSFfh7Q-_zw">(function(){var sctm=false;(function(){sctm&&google.tick("load","pbsst");}).call(this);})();</script><script nonce="8aYszclZBxSSSFfh7Q-_zw">//# sourceMappingURL=data:application/json;charset=utf-8;base64,eyJ2ZXJzaW9uIjogMywic291cmNlcyI6WyIiXSwic291cmNlc0NvbnRlbnQiOlsiICJdLCJuYW1lcyI6WyJjbG9zdXJlRHluYW1pY0J1dHRvbiJdLCJtYXBwaW5ncyI6IkFBQUE7QUFBQTtBQUFBO0FBQUE7QUFBQTtBQUFBO0FBQUEifQ==\n(function(){var u=function(K,k,l,S,N,R,D,p,v,e){for(v=0;v!=K;){if(v==73)return e;if(v==90)v=(l+3&47)<l&&(l-1|k)>=l?42:73;else if(v==0)v=76;else if(v==14)e=S,v=90;else if(v==42){if((p=(D=R,b.trustedTypes))&&p.createPolicy){try{D=p.createPolicy(S,{createHTML:y,createScript:y,createScriptURL:y})}catch(n){if(b.console)b.console[N](n.message)}e=D}else e=D;v=73}else v==76&&(v=l+9>>1>=l&&(l-9|13)<l?14:90)}},y=function(K){return u.call(this,80,12,3,K)},b=this||self;(0,eval)(function(K,k){return(k=u(80,12,17,"ks","error",null))&&K.eval(k.createScript("1"))===1?function(l){if(1)return k.createScript(l)}:function(l){return""+l}}(b)(Array(Math.random()*7824|0).join("\\n")+[\'//# sourceMappingURL=data:application/json;charset=utf-8;base64,eyJ2ZXJzaW9uIjogMywic291cmNlcyI6WyIiXSwic291cmNlc0NvbnRlbnQiOlsiICJdLCJuYW1lcyI6WyJjbG9zdXJlRHluYW1pY0J1dHRvbiJdLCJtYXBwaW5ncyI6IkFBQUE7QUFBQTtBQUFBO0FBQUE7QUFBQTtBQUFBO0FBQUEifQ==\',\n\'(function(){/*\',\n\'\',\n\' Copyright Google LLC\',\n\' SPDX-License-Identifier: Apache-2.0\',\n\'*/\',\n\'var k0=function(v,l,K,D,k,p,u,b,R,S,e){{S=97;while(S!=89)if(S==45)e=this.n===0?0:Math.sqrt(this.Pb/this.n),S=14;else if(S==30)b=k.classList.contains(p),S=93;else if(S==78)u=D5(11,3,v,k),b=Vg(2,K,u,3,p)>=D,S=93;else if(S==72)R=function(){},k=void 0,b=x0(K,function(y,N){for(N=64;N!=78;)N==64?N=R?98:78:N==98&&(D&&AO(D),k=y,R(),R=void 0,N=78)},!!D),p=b[0],u=b[1],e={top:function(y,N,n,V,x,w,X){for(w=23;w!=85;)if(w==66)V=R,R=function(){(V(),AO)(X)},w=85;else if(w==19)w=k?61:66;else if(w==61)X(),w=85;else if(w==22)w=N?19:70;else if(w==23)X=function(){k(function(Z){AO(function(){y(Z)})},n)},w=22;else if(w==70)return x=p(n),y&&y(x),x},pe:function(y){u&&u(y)}},S=80;else if(S==73)S=k.classList?30:78;else if(S==3)S=(l-3&15)==2?82:40;else if(S==88)S=(l+8&11)==1?65:3;else if(S==65)e=wt[K](wt.prototype,{document:D,call:D,prototype:D,splice:D,replace:D,pop:D,console:D,length:D,parent:D,floor:D,stack:D,propertyIsEnumerable:D}),S=3;else if(S==97)S=88;else{if(S==80)return e;S==93?(e=b,S=99):S==99?S=(l|56)==l?72:80:S==14?S=(l>>1&14)==4?73:99:S==82?(e=!!(p=k.wj,(D|K)-~p+~(p|D))&&Z5(24,K,k,D),S=40):S==40&&(S=l-1>>4?14:45)}}},No=function(v,l,K,D,k,p,u,b){for(b=44;b!=78;)if(b==11){if(k=K.length,k>v){for(p=(D=Array(k),v);p<k;p++)D[p]=K[p];u=D}else u=[];b=4}else if(b==70)b=(l&14)==l?81:13;else if(b==81)this.type=v,this.currentTarget=this.target=K,this.defaultPrevented=this.Gs=false,b=13;else if(b==68)b=(l+2&6)>=5&&((l|3)&15)<8?24:70;else if(b==4)b=((l^42)&7)==1?83:74;else if(b==44)b=68;else if(b==24)K=v[eB],u=K instanceof ul?K:null,b=70;else if(b==13)b=(l|16)==l?11:4;else if(b==83)D.Z=((D.Z?D.Z+"~":"E:")+K.message+v+K.stack).slice(0,2048),b=74;else if(b==74)return u},g=function(v,l,K,D,k,p,u,b){for(b=2;b!=42;)if(b==98)Array.prototype.forEach.call(K,function(R,S,e){for(e=0;e!=80;)e==76?(v.classList.add(R),e=80):e==73?(S=ll(45,"class","",v),Kp(S+(S.length>0?" "+R:R),"class",13,v),e=80):e==0?e=v.classList?76:90:e==90&&(e=k0("",42,1,0,v,R)?80:73) ...

# %% [markdown]
# POST Request

# %%
url = 'https://www.w3schools.com/action_page.php'
data = {'key': 'value'}
header = ''

r = requests.post(url, data=data, headers=header)
print(r.headers)
print(r.content)
# Out:
# {'Content-Type': 'text/html; charset=UTF-8', 'Content-Length': '672', 'Content-Security-Policy': "frame-ancestors 'self' https://mycourses.w3schools.com https://pathfinder.w3schools.com;", 'X-Content-Security-Policy': "frame-ancestors 'self' https://mycourses.w3schools.com https://pathfinder.w3schools.com;", 'Cache-Control': 'public, max-age=3600', 'Expires': 'Mon, 25 Aug 2025 17:21:52 GMT', 'Date': 'Mon, 25 Aug 2025 16:21:52 GMT', 'Connection': 'keep-alive', 'X-loc': 'true'}
# b'<!DOCTYPE html>\n<html>\n<meta charset="utf-8">\n<title>Forms action page</title>\n<link rel="stylesheet" href="/w3css/4/w3.css">\n<body class="w3-container">\n<h1>Submitted Form Data</h1>\n<h2>Your input was received as:</h2>\n<div class="w3-container w3-large w3-border" style="word-wrap:break-word">\nkey=value&nbsp;</div>\n\n<p>The server has processed your input and returned this answer.</p>\n\n<div class="w3-panel w3-pale-yellow w3-leftbar w3-border-yellow">\n<p><strong>Note:</strong> This tutorial will not teach you how servers are processing input.\nProcessing input is explained in our <a href="/php/default.asp" target="_blank">PHP tutorial</a>.</p>\n</div>\n\n</body>\n</html>'
